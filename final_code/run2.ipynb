# %%
epochs_=100
batch_size_=15

# %%
import os, os.path
import re
import pandas as pd
import numpy as np
import cv2
import requests
from PIL import Image
from io import BytesIO
from imageio import imread
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as keras
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import shutil
import time
import albumentations as A

# %%
########################################################################################################################
####################################           KeyVars           #######################################################
########################################################################################################################

# %%
directory="before_augment/"
subdir=["benign_image/","benign_mask/","malignant_image/","malignant_mask/","normal_image/","normal_mask/"]
dataset=['dataset/','train/','test/','validation/']

# %%
########################################################################################################################
####################################        train_test_valid      ######################################################
########################################################################################################################

# %%
train_test_valid=[[[],[]],[[],[]],[[],[]]]

for i in range(1,len(dataset)):
    for j in range(3):
        for k in range(len(os.listdir(dataset[0]+dataset[i]+subdir[j*2]))):
            train_test_valid[i-1][0].append(plt.imread(dataset[0]+dataset[i]+subdir[j*2]+str(k)+".jpeg"))
            train_test_valid[i-1][1].append(plt.imread(dataset[0]+dataset[i]+subdir[j*2+1]+str(k)+".jpeg"))

X_train= np.asarray(train_test_valid[0][0],dtype=np.float32)/255
y_train= np.asarray(train_test_valid[0][1],dtype=np.float32)/255
X_test = np.asarray(train_test_valid[1][0],dtype=np.float32)/255
y_test = np.asarray(train_test_valid[1][1],dtype=np.float32)/255
X_valid= np.asarray(train_test_valid[2][0],dtype=np.float32)/255
y_valid= np.asarray(train_test_valid[2][1],dtype=np.float32)/255

X_train,y_train=shuffle(X_train, y_train)
X_test,y_test=shuffle(X_test, y_test)
X_valid,y_valid=shuffle(X_valid, y_valid)

# %%
########################################################################################################################
####################################        SegregateData        #######################################################
########################################################################################################################

# %%
def SegregateData(dataset,subdir):
    
    l=[[[[],[]],[[],[]],[[],[]]],[[[],[]],[[],[]],[[],[]]],[[[],[]],[[],[]],[[],[]]]]
    
    for i in range(1,4):
        for k in range(3):
            l1=[]
            for j in range(len(os.listdir(dataset[0]+dataset[i]+subdir[k*2]))):
                l1.append(plt.imread(dataset[0]+dataset[i]+subdir[k*2]+os.listdir(dataset[0]+dataset[i]+subdir[k*2])[j]))

            l2=[]
            for j in range(len(os.listdir(dataset[0]+dataset[i]+subdir[k*2+1]))):
                l2.append(plt.imread(dataset[0]+dataset[i]+subdir[k*2+1]+os.listdir(dataset[0]+dataset[i]+subdir[k*2+1])[j]))
            
            l[i-1][k][0]=l1
            l[i-1][k][1]=l2
    return l

l=SegregateData(dataset,subdir)

# X_train_benign        --> l[0][0][0]
# y_train_benign        --> l[0][0][1]
# X_train_malgiant      --> l[0][1][0]
# y_train_malgiant      --> l[0][1][1]
# X_train_normal        --> l[0][2][0]
# y_train_normal        --> l[0][2][1]

# X_test_benign         --> l[1][0][0]
# y_test_benign         --> l[1][0][1]
# X_test_malgiant       --> l[1][1][0]
# y_test_malgiant       --> l[1][1][1]
# X_test_normal         --> l[1][2][0]
# y_test_normal         --> l[1][2][1]

# X_validation_benign   --> l[2][0][0]
# y_validation_benign   --> l[2][0][1]
# X_validation_malgiant --> l[2][1][0]
# y_validation_malgiant --> l[2][1][1]
# X_validation_normal   --> l[2][2][0]
# y_validation_normal   --> l[2][2][1]

# %%
########################################################################################################################
####################################         UNET MODEL          #######################################################
########################################################################################################################

# %%
def conv_block(input_, num_filters):
    
#     conv2D_1 = Conv2D(filters = num_filters,kernel_size =  3, padding="same")(input_)
    conv2D_1 = Conv2D(filters = num_filters,kernel_size =  3, kernel_initializer = 'he_normal', padding="same")(input_)
    batch1 = BatchNormalization()(conv2D_1)
    act1 = Activation("relu")(batch1)

#     conv2D_2 = Conv2D(filters = num_filters,kernel_size =  3, padding="same")(act1)
    conv2D_2 = Conv2D(filters = num_filters,kernel_size =  3, kernel_initializer = 'he_normal', padding="same")(act1)
    batch2 = BatchNormalization()(conv2D_2)
    act2 = Activation("relu")(batch2)

    return act2

# count=0

def encoder_block(input_, num_filters):
#     global count
#     count+=1
#     print(count)
    conv = conv_block(input_, num_filters)
#     if count==4:
#         drop = Dropout(0.075)(conv)
#         pool = MaxPool2D((2, 2))(drop)
#         count=0
#         return conv, pool
    pool = MaxPool2D((2, 2))(conv)
    drop = Dropout(0.075)(pool)
    return conv, drop

def decoder_block(input_, skip_features, num_filters):
    x = Conv2DTranspose(filters = num_filters,kernel_size = (2, 2), strides=2, padding="same")(input_)
    x = Concatenate()([x, skip_features])
    x = Dropout(0.075)(x)
    x = conv_block(x, num_filters)
    return x

def unet_build(input_shape):
    
    inputs = Input(input_shape)
    
    conv1, pool1 = encoder_block(inputs, 16)
    conv2, pool2 = encoder_block(pool1, 32)
    conv3, pool3 = encoder_block(pool2, 64) 
    conv4, pool4 = encoder_block(pool3, 128) 

    bridge = conv_block(pool4, 256)

    decoder_1 = decoder_block(bridge, conv4, 128)
    decoder_2 = decoder_block(decoder_1, conv3, 64)
    decoder_3 = decoder_block(decoder_2, conv2, 32)
    decoder_4 = decoder_block(decoder_3, conv1, 16)

    outputs = Conv2D(1, (1,1), padding="same", activation="sigmoid") (decoder_4)
#     outputs = Conv2D(1, 1, padding="same") (decoder_4)

    model = Model(inputs, outputs, name="U-Net")
    return model

def improvised_unet_build(input_shape):
    
    inputs = Input(input_shape)
    
    conv1, pool1 = encoder_block(inputs, 16)
    conv2, pool2 = encoder_block(pool1, 32)
    conv3, pool3 = encoder_block(pool2, 64) 
    conv4, pool4 = encoder_block(pool3, 128) 

    bridge = conv_block(pool4, 256)

    decoder_1 = decoder_block(bridge, conv4, 128)
    decoder_2 = decoder_block(decoder_1, conv3, 64)
    decoder_3 = decoder_block(decoder_2, conv2, 32)
    
#     decoder_4 = decoder_block(decoder_3, conv1, 16)

    x = Conv2DTranspose(filters = 16,kernel_size = (2, 2), strides=2, padding="same")(decoder_3)
    x = Concatenate()([x, conv1])
    x = Dropout(0.075)(x)
    
    x1 = conv_block(x, 16)
    y1_output = Conv2D(1, 1, padding="same", activation="sigmoid",name='grayscale') (x1)

    x2 = conv_block(x, 16)
    y2_output = Conv2D(3, 1, padding="same", activation="sigmoid",name='colour') (x2)
    
    model = Model(inputs=inputs, outputs=[y1_output, y2_output], name="U-Net")
    return model
#     outputs = Conv2D(1, 1, padding="same") (decoder_4)

def DiceAccuracy(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    inputs = keras.flatten(inputs)
    targets = keras.flatten(targets)
    
    intersection = keras.sum(targets*inputs,keepdims=True)
    dice = (2*intersection + smooth) / (keras.sum(targets) + keras.sum(inputs) + smooth)
    return dice

# %%
input_shape = (256, 256, 3)
unet_model = unet_build(input_shape)
unet_model.summary()

# input_shape = (256, 256, 3)
# improvised_unet_model = improvised_unet_build(input_shape)
# improvised_unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256, 256, 16) 64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 256, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 16) 2320        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 256, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 16) 0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 4640        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 128, 128, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   18496       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 128)  73856       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 128)  147584      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 128)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 256)  295168      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 256)  1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 128)  131200      activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 128)  295040      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 64)   32832       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_5[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64, 64, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 64)   73792       dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 32) 8224        activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 128, 64) 0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 32) 18464       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 128, 128, 32) 128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 128, 128, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 32) 9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128, 128, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 128, 128, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 16) 2064        activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_7[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256, 256, 32) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 16) 4624        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 256, 256, 16) 64          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 256, 256, 16) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 16) 2320        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 256, 256, 16) 64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 256, 256, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 1)  17          activation_35[0][0]
# ==================================================================================================
# Total params: 1,946,993
# Trainable params: 1,944,049
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
unet_model.compile(optimizer='adam', loss='binary_crossentropy',metrics=[DiceAccuracy])

# improvised_unet_model.compile(optimizer='adam',
#                               loss={'grayscale': 'binary_crossentropy', 'colour': 'mse'},
#                               metrics={'grayscale': DiceAccuracy, 'colour': tf.keras.metrics.Accuracy()},
#                               )

# %%
filepath='_BCE-1e-3-x0_new'
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_DiceAccuracy',mode='max',verbose=1,save_best_only=True)
callbacks = [checkpoint]

# %%
history = unet_model.fit(X_train,y_train,batch_size=batch_size_,epochs=epochs_,validation_data=(X_valid,y_valid),callbacks=callbacks)
# history = improvised_unet_model.fit(X_train,(y_train,X_train) ,batch_size=25,epochs=300,validation_data=(X_valid,(y_valid,X_valid)),callbacks=callbacks)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 28s 240ms/step - loss: 0.5028 - DiceAccuracy: 0.1113 - val_loss: 0.9955 - val_DiceAccuracy: 0.1283
#
# Epoch 00001: val_DiceAccuracy improved from -inf to 0.12835, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 2/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.3373 - DiceAccuracy: 0.1050 - val_loss: 0.3692 - val_DiceAccuracy: 0.1133
#
# Epoch 00002: val_DiceAccuracy did not improve from 0.12835
# Epoch 3/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.2764 - DiceAccuracy: 0.1363 - val_loss: 3.0671 - val_DiceAccuracy: 0.1582
#
# Epoch 00003: val_DiceAccuracy improved from 0.12835 to 0.15817, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 4/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.2268 - DiceAccuracy: 0.2007 - val_loss: 2.6498 - val_DiceAccuracy: 0.1557
#
# Epoch 00004: val_DiceAccuracy did not improve from 0.15817
# Epoch 5/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.1968 - DiceAccuracy: 0.2524 - val_loss: 1.2337 - val_DiceAccuracy: 0.1826
#
# Epoch 00005: val_DiceAccuracy improved from 0.15817 to 0.18265, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 6/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1824 - DiceAccuracy: 0.2805 - val_loss: 0.4023 - val_DiceAccuracy: 0.2924
#
# Epoch 00006: val_DiceAccuracy improved from 0.18265 to 0.29235, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 7/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1636 - DiceAccuracy: 0.3439 - val_loss: 0.3017 - val_DiceAccuracy: 0.3155
#
# Epoch 00007: val_DiceAccuracy improved from 0.29235 to 0.31546, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 8/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1561 - DiceAccuracy: 0.3608 - val_loss: 0.5384 - val_DiceAccuracy: 0.3042
#
# Epoch 00008: val_DiceAccuracy did not improve from 0.31546
# Epoch 9/100
# 60/60 [==============================] - 11s 176ms/step - loss: 0.1534 - DiceAccuracy: 0.3711 - val_loss: 0.2196 - val_DiceAccuracy: 0.3795
#
# Epoch 00009: val_DiceAccuracy improved from 0.31546 to 0.37950, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 10/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1478 - DiceAccuracy: 0.3970 - val_loss: 0.2215 - val_DiceAccuracy: 0.3770
#
# Epoch 00010: val_DiceAccuracy did not improve from 0.37950
# Epoch 11/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.1425 - DiceAccuracy: 0.4155 - val_loss: 0.1609 - val_DiceAccuracy: 0.4026
#
# Epoch 00011: val_DiceAccuracy improved from 0.37950 to 0.40260, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 12/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1322 - DiceAccuracy: 0.4561 - val_loss: 0.1635 - val_DiceAccuracy: 0.4181
#
# Epoch 00012: val_DiceAccuracy improved from 0.40260 to 0.41814, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 13/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1306 - DiceAccuracy: 0.4653 - val_loss: 0.1591 - val_DiceAccuracy: 0.4325
#
# Epoch 00013: val_DiceAccuracy improved from 0.41814 to 0.43246, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 14/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1330 - DiceAccuracy: 0.4549 - val_loss: 0.1869 - val_DiceAccuracy: 0.3777
#
# Epoch 00014: val_DiceAccuracy did not improve from 0.43246
# Epoch 15/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.1236 - DiceAccuracy: 0.4919 - val_loss: 0.1625 - val_DiceAccuracy: 0.4313
#
# Epoch 00015: val_DiceAccuracy did not improve from 0.43246
# Epoch 16/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.1218 - DiceAccuracy: 0.4965 - val_loss: 0.1646 - val_DiceAccuracy: 0.4527
#
# Epoch 00016: val_DiceAccuracy improved from 0.43246 to 0.45274, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 17/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1217 - DiceAccuracy: 0.4899 - val_loss: 0.1578 - val_DiceAccuracy: 0.5047
#
# Epoch 00017: val_DiceAccuracy improved from 0.45274 to 0.50466, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 18/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.1168 - DiceAccuracy: 0.5200 - val_loss: 0.1653 - val_DiceAccuracy: 0.4902
#
# Epoch 00018: val_DiceAccuracy did not improve from 0.50466
# Epoch 19/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.1090 - DiceAccuracy: 0.5533 - val_loss: 0.1559 - val_DiceAccuracy: 0.4950
#
# Epoch 00019: val_DiceAccuracy did not improve from 0.50466
# Epoch 20/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.1075 - DiceAccuracy: 0.5547 - val_loss: 0.1648 - val_DiceAccuracy: 0.4960
#
# Epoch 00020: val_DiceAccuracy did not improve from 0.50466
# Epoch 21/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.1030 - DiceAccuracy: 0.5808 - val_loss: 0.1676 - val_DiceAccuracy: 0.4678
#
# Epoch 00021: val_DiceAccuracy did not improve from 0.50466
# Epoch 22/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.1015 - DiceAccuracy: 0.5748 - val_loss: 0.1680 - val_DiceAccuracy: 0.4933
#
# Epoch 00022: val_DiceAccuracy did not improve from 0.50466
# Epoch 23/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0938 - DiceAccuracy: 0.6100 - val_loss: 0.1693 - val_DiceAccuracy: 0.4786
#
# Epoch 00023: val_DiceAccuracy did not improve from 0.50466
# Epoch 24/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0993 - DiceAccuracy: 0.5835 - val_loss: 0.1763 - val_DiceAccuracy: 0.5025
#
# Epoch 00024: val_DiceAccuracy did not improve from 0.50466
# Epoch 25/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0897 - DiceAccuracy: 0.6211 - val_loss: 0.1756 - val_DiceAccuracy: 0.5284
#
# Epoch 00025: val_DiceAccuracy improved from 0.50466 to 0.52845, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 26/100
# 60/60 [==============================] - 11s 174ms/step - loss: 0.0874 - DiceAccuracy: 0.6365 - val_loss: 0.1701 - val_DiceAccuracy: 0.5404
#
# Epoch 00026: val_DiceAccuracy improved from 0.52845 to 0.54040, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 27/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0842 - DiceAccuracy: 0.6405 - val_loss: 0.1743 - val_DiceAccuracy: 0.4899
#
# Epoch 00027: val_DiceAccuracy did not improve from 0.54040
# Epoch 28/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.0804 - DiceAccuracy: 0.6629 - val_loss: 0.1713 - val_DiceAccuracy: 0.5339
#
# Epoch 00028: val_DiceAccuracy did not improve from 0.54040
# Epoch 29/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0726 - DiceAccuracy: 0.6909 - val_loss: 0.1722 - val_DiceAccuracy: 0.5200
#
# Epoch 00029: val_DiceAccuracy did not improve from 0.54040
# Epoch 30/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0680 - DiceAccuracy: 0.7065 - val_loss: 0.1992 - val_DiceAccuracy: 0.5088
#
# Epoch 00030: val_DiceAccuracy did not improve from 0.54040
# Epoch 31/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0643 - DiceAccuracy: 0.7274 - val_loss: 0.2015 - val_DiceAccuracy: 0.5322
#
# Epoch 00031: val_DiceAccuracy did not improve from 0.54040
# Epoch 32/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0623 - DiceAccuracy: 0.7346 - val_loss: 0.1641 - val_DiceAccuracy: 0.5522
#
# Epoch 00032: val_DiceAccuracy improved from 0.54040 to 0.55222, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 33/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0663 - DiceAccuracy: 0.7152 - val_loss: 0.2032 - val_DiceAccuracy: 0.4858
#
# Epoch 00033: val_DiceAccuracy did not improve from 0.55222
# Epoch 34/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0570 - DiceAccuracy: 0.7495 - val_loss: 0.1700 - val_DiceAccuracy: 0.5778
#
# Epoch 00034: val_DiceAccuracy improved from 0.55222 to 0.57778, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 35/100
# 60/60 [==============================] - 11s 174ms/step - loss: 0.0520 - DiceAccuracy: 0.7765 - val_loss: 0.1693 - val_DiceAccuracy: 0.5718
#
# Epoch 00035: val_DiceAccuracy did not improve from 0.57778
# Epoch 36/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0543 - DiceAccuracy: 0.7619 - val_loss: 0.1756 - val_DiceAccuracy: 0.5868
#
# Epoch 00036: val_DiceAccuracy improved from 0.57778 to 0.58678, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 37/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0505 - DiceAccuracy: 0.7793 - val_loss: 0.1994 - val_DiceAccuracy: 0.5144
#
# Epoch 00037: val_DiceAccuracy did not improve from 0.58678
# Epoch 38/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0465 - DiceAccuracy: 0.7948 - val_loss: 0.1777 - val_DiceAccuracy: 0.6120
#
# Epoch 00038: val_DiceAccuracy improved from 0.58678 to 0.61204, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 39/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0444 - DiceAccuracy: 0.8070 - val_loss: 0.1838 - val_DiceAccuracy: 0.6062
#
# Epoch 00039: val_DiceAccuracy did not improve from 0.61204
# Epoch 40/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.0396 - DiceAccuracy: 0.8231 - val_loss: 0.1749 - val_DiceAccuracy: 0.5914
#
# Epoch 00040: val_DiceAccuracy did not improve from 0.61204
# Epoch 41/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0430 - DiceAccuracy: 0.8023 - val_loss: 0.1939 - val_DiceAccuracy: 0.5817
#
# Epoch 00041: val_DiceAccuracy did not improve from 0.61204
# Epoch 42/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0402 - DiceAccuracy: 0.8231 - val_loss: 0.1757 - val_DiceAccuracy: 0.6219
#
# Epoch 00042: val_DiceAccuracy improved from 0.61204 to 0.62194, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 43/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0364 - DiceAccuracy: 0.8373 - val_loss: 0.1835 - val_DiceAccuracy: 0.6102
#
# Epoch 00043: val_DiceAccuracy did not improve from 0.62194
# Epoch 44/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0382 - DiceAccuracy: 0.8262 - val_loss: 0.2175 - val_DiceAccuracy: 0.5456
#
# Epoch 00044: val_DiceAccuracy did not improve from 0.62194
# Epoch 45/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0348 - DiceAccuracy: 0.8417 - val_loss: 0.2082 - val_DiceAccuracy: 0.5820
#
# Epoch 00045: val_DiceAccuracy did not improve from 0.62194
# Epoch 46/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0379 - DiceAccuracy: 0.8284 - val_loss: 0.1866 - val_DiceAccuracy: 0.6075
#
# Epoch 00046: val_DiceAccuracy did not improve from 0.62194
# Epoch 47/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0355 - DiceAccuracy: 0.8395 - val_loss: 0.1968 - val_DiceAccuracy: 0.5923
#
# Epoch 00047: val_DiceAccuracy did not improve from 0.62194
# Epoch 48/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0325 - DiceAccuracy: 0.8504 - val_loss: 0.1825 - val_DiceAccuracy: 0.6195
#
# Epoch 00048: val_DiceAccuracy did not improve from 0.62194
# Epoch 49/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0360 - DiceAccuracy: 0.8408 - val_loss: 0.1865 - val_DiceAccuracy: 0.6063
#
# Epoch 00049: val_DiceAccuracy did not improve from 0.62194
# Epoch 50/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0284 - DiceAccuracy: 0.8681 - val_loss: 0.2337 - val_DiceAccuracy: 0.5588
#
# Epoch 00050: val_DiceAccuracy did not improve from 0.62194
# Epoch 51/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0288 - DiceAccuracy: 0.8637 - val_loss: 0.2419 - val_DiceAccuracy: 0.5450
#
# Epoch 00051: val_DiceAccuracy did not improve from 0.62194
# Epoch 52/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0287 - DiceAccuracy: 0.8636 - val_loss: 0.1942 - val_DiceAccuracy: 0.6114
#
# Epoch 00052: val_DiceAccuracy did not improve from 0.62194
# Epoch 53/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0254 - DiceAccuracy: 0.8831 - val_loss: 0.2166 - val_DiceAccuracy: 0.6100
#
# Epoch 00053: val_DiceAccuracy did not improve from 0.62194
# Epoch 54/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0244 - DiceAccuracy: 0.8919 - val_loss: 0.2039 - val_DiceAccuracy: 0.6229
#
# Epoch 00054: val_DiceAccuracy improved from 0.62194 to 0.62292, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 55/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0262 - DiceAccuracy: 0.8753 - val_loss: 0.2023 - val_DiceAccuracy: 0.6341
#
# Epoch 00055: val_DiceAccuracy improved from 0.62292 to 0.63410, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 56/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0256 - DiceAccuracy: 0.8787 - val_loss: 0.2084 - val_DiceAccuracy: 0.6025
#
# Epoch 00056: val_DiceAccuracy did not improve from 0.63410
# Epoch 57/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0245 - DiceAccuracy: 0.8872 - val_loss: 0.2138 - val_DiceAccuracy: 0.6287
#
# Epoch 00057: val_DiceAccuracy did not improve from 0.63410
# Epoch 58/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0220 - DiceAccuracy: 0.8991 - val_loss: 0.1973 - val_DiceAccuracy: 0.6485
#
# Epoch 00058: val_DiceAccuracy improved from 0.63410 to 0.64849, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 59/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0239 - DiceAccuracy: 0.8948 - val_loss: 0.1903 - val_DiceAccuracy: 0.6330
#
# Epoch 00059: val_DiceAccuracy did not improve from 0.64849
# Epoch 60/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0222 - DiceAccuracy: 0.8990 - val_loss: 0.2321 - val_DiceAccuracy: 0.6023
#
# Epoch 00060: val_DiceAccuracy did not improve from 0.64849
# Epoch 61/100
# 60/60 [==============================] - 10s 173ms/step - loss: 0.0236 - DiceAccuracy: 0.8892 - val_loss: 0.2007 - val_DiceAccuracy: 0.6486
#
# Epoch 00061: val_DiceAccuracy improved from 0.64849 to 0.64862, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 62/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0225 - DiceAccuracy: 0.8973 - val_loss: 0.2152 - val_DiceAccuracy: 0.6366
#
# Epoch 00062: val_DiceAccuracy did not improve from 0.64862
# Epoch 63/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0210 - DiceAccuracy: 0.9041 - val_loss: 0.2272 - val_DiceAccuracy: 0.6126
#
# Epoch 00063: val_DiceAccuracy did not improve from 0.64862
# Epoch 64/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0188 - DiceAccuracy: 0.9132 - val_loss: 0.2256 - val_DiceAccuracy: 0.6191
#
# Epoch 00064: val_DiceAccuracy did not improve from 0.64862
# Epoch 65/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0200 - DiceAccuracy: 0.9057 - val_loss: 0.1969 - val_DiceAccuracy: 0.6490
#
# Epoch 00065: val_DiceAccuracy improved from 0.64862 to 0.64900, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 66/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0186 - DiceAccuracy: 0.9157 - val_loss: 0.2110 - val_DiceAccuracy: 0.6494
#
# Epoch 00066: val_DiceAccuracy improved from 0.64900 to 0.64944, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 67/100
# 60/60 [==============================] - 11s 174ms/step - loss: 0.0183 - DiceAccuracy: 0.9146 - val_loss: 0.2131 - val_DiceAccuracy: 0.6653
#
# Epoch 00067: val_DiceAccuracy improved from 0.64944 to 0.66529, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 68/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0177 - DiceAccuracy: 0.9192 - val_loss: 0.2212 - val_DiceAccuracy: 0.6449
#
# Epoch 00068: val_DiceAccuracy did not improve from 0.66529
# Epoch 69/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0175 - DiceAccuracy: 0.9172 - val_loss: 0.2447 - val_DiceAccuracy: 0.6111
#
# Epoch 00069: val_DiceAccuracy did not improve from 0.66529
# Epoch 70/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0173 - DiceAccuracy: 0.9208 - val_loss: 0.2365 - val_DiceAccuracy: 0.6297
#
# Epoch 00070: val_DiceAccuracy did not improve from 0.66529
# Epoch 71/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0185 - DiceAccuracy: 0.9172 - val_loss: 0.2320 - val_DiceAccuracy: 0.6199
#
# Epoch 00071: val_DiceAccuracy did not improve from 0.66529
# Epoch 72/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0206 - DiceAccuracy: 0.9080 - val_loss: 0.2149 - val_DiceAccuracy: 0.6616
#
# Epoch 00072: val_DiceAccuracy did not improve from 0.66529
# Epoch 73/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0179 - DiceAccuracy: 0.9178 - val_loss: 0.2037 - val_DiceAccuracy: 0.6644
#
# Epoch 00073: val_DiceAccuracy did not improve from 0.66529
# Epoch 74/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0170 - DiceAccuracy: 0.9219 - val_loss: 0.2536 - val_DiceAccuracy: 0.5931
#
# Epoch 00074: val_DiceAccuracy did not improve from 0.66529
# Epoch 75/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0199 - DiceAccuracy: 0.9069 - val_loss: 0.2218 - val_DiceAccuracy: 0.6585
#
# Epoch 00075: val_DiceAccuracy did not improve from 0.66529
# Epoch 76/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0258 - DiceAccuracy: 0.8941 - val_loss: 0.2448 - val_DiceAccuracy: 0.5814
#
# Epoch 00076: val_DiceAccuracy did not improve from 0.66529
# Epoch 77/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0296 - DiceAccuracy: 0.8659 - val_loss: 0.2189 - val_DiceAccuracy: 0.5998
#
# Epoch 00077: val_DiceAccuracy did not improve from 0.66529
# Epoch 78/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0265 - DiceAccuracy: 0.8821 - val_loss: 0.2129 - val_DiceAccuracy: 0.5982
#
# Epoch 00078: val_DiceAccuracy did not improve from 0.66529
# Epoch 79/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0265 - DiceAccuracy: 0.8815 - val_loss: 0.2071 - val_DiceAccuracy: 0.6104
#
# Epoch 00079: val_DiceAccuracy did not improve from 0.66529
# Epoch 80/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0246 - DiceAccuracy: 0.8895 - val_loss: 0.2184 - val_DiceAccuracy: 0.6393
#
# Epoch 00080: val_DiceAccuracy did not improve from 0.66529
# Epoch 81/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0187 - DiceAccuracy: 0.9143 - val_loss: 0.2287 - val_DiceAccuracy: 0.6426
#
# Epoch 00081: val_DiceAccuracy did not improve from 0.66529
# Epoch 82/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0159 - DiceAccuracy: 0.9261 - val_loss: 0.2593 - val_DiceAccuracy: 0.6047
#
# Epoch 00082: val_DiceAccuracy did not improve from 0.66529
# Epoch 83/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0156 - DiceAccuracy: 0.9268 - val_loss: 0.2573 - val_DiceAccuracy: 0.6201
#
# Epoch 00083: val_DiceAccuracy did not improve from 0.66529
# Epoch 84/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0158 - DiceAccuracy: 0.9279 - val_loss: 0.2577 - val_DiceAccuracy: 0.6129
#
# Epoch 00084: val_DiceAccuracy did not improve from 0.66529
# Epoch 85/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0145 - DiceAccuracy: 0.9342 - val_loss: 0.2416 - val_DiceAccuracy: 0.6465
#
# Epoch 00085: val_DiceAccuracy did not improve from 0.66529
# Epoch 86/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0142 - DiceAccuracy: 0.9340 - val_loss: 0.2476 - val_DiceAccuracy: 0.6480
#
# Epoch 00086: val_DiceAccuracy did not improve from 0.66529
# Epoch 87/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0139 - DiceAccuracy: 0.9371 - val_loss: 0.2451 - val_DiceAccuracy: 0.6417
#
# Epoch 00087: val_DiceAccuracy did not improve from 0.66529
# Epoch 88/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0134 - DiceAccuracy: 0.9382 - val_loss: 0.2514 - val_DiceAccuracy: 0.6439
#
# Epoch 00088: val_DiceAccuracy did not improve from 0.66529
# Epoch 89/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0132 - DiceAccuracy: 0.9403 - val_loss: 0.2547 - val_DiceAccuracy: 0.6448
#
# Epoch 00089: val_DiceAccuracy did not improve from 0.66529
# Epoch 90/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0135 - DiceAccuracy: 0.9393 - val_loss: 0.2582 - val_DiceAccuracy: 0.6461
#
# Epoch 00090: val_DiceAccuracy did not improve from 0.66529
# Epoch 91/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0139 - DiceAccuracy: 0.9370 - val_loss: 0.2511 - val_DiceAccuracy: 0.6306
#
# Epoch 00091: val_DiceAccuracy did not improve from 0.66529
# Epoch 92/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0131 - DiceAccuracy: 0.9401 - val_loss: 0.2570 - val_DiceAccuracy: 0.6384
#
# Epoch 00092: val_DiceAccuracy did not improve from 0.66529
# Epoch 93/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0125 - DiceAccuracy: 0.9429 - val_loss: 0.2539 - val_DiceAccuracy: 0.6451
#
# Epoch 00093: val_DiceAccuracy did not improve from 0.66529
# Epoch 94/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0126 - DiceAccuracy: 0.9423 - val_loss: 0.2651 - val_DiceAccuracy: 0.6337
#
# Epoch 00094: val_DiceAccuracy did not improve from 0.66529
# Epoch 95/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0124 - DiceAccuracy: 0.9439 - val_loss: 0.2550 - val_DiceAccuracy: 0.6513
#
# Epoch 00095: val_DiceAccuracy did not improve from 0.66529
# Epoch 96/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0127 - DiceAccuracy: 0.9416 - val_loss: 0.2588 - val_DiceAccuracy: 0.6421
#
# Epoch 00096: val_DiceAccuracy did not improve from 0.66529
# Epoch 97/100
# 60/60 [==============================] - 10s 174ms/step - loss: 0.0130 - DiceAccuracy: 0.9395 - val_loss: 0.2572 - val_DiceAccuracy: 0.6546
#
# Epoch 00097: val_DiceAccuracy did not improve from 0.66529
# Epoch 98/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0125 - DiceAccuracy: 0.9445 - val_loss: 0.2584 - val_DiceAccuracy: 0.6460
#
# Epoch 00098: val_DiceAccuracy did not improve from 0.66529
# Epoch 99/100
# 60/60 [==============================] - 10s 175ms/step - loss: 0.0126 - DiceAccuracy: 0.9440 - val_loss: 0.2470 - val_DiceAccuracy: 0.6683
#
# Epoch 00099: val_DiceAccuracy improved from 0.66529 to 0.66827, saving model to _BCE-1e-3-x0_new
# INFO:tensorflow:Assets written to: _BCE-1e-3-x0_new\assets
# Epoch 100/100
# 60/60 [==============================] - 11s 173ms/step - loss: 0.0117 - DiceAccuracy: 0.9464 - val_loss: 0.2590 - val_DiceAccuracy: 0.6581
#
# Epoch 00100: val_DiceAccuracy did not improve from 0.66827

# %%
model_best = load_model(filepath,custom_objects={'DiceAccuracy':DiceAccuracy,})

# %%
def predict_data():
    
    results=['results','train','test','valid']
    
    dirs=[('/test/test_tumor/','/test/test_true/','/test/test_predicted/'),
      ('/train/train_tumor/','/train/train_true/','/train/train_predicted/'),
      ('/valid/valid_tumor/','/valid/valid_true/','/valid/valid_predicted/')
     ]
    
    data_saves=[(X_test,y_test),(X_train,y_train),(X_valid,y_valid)]
    
    for x in range(len(results)):
        if(x==0):
            if os.path.exists(results[x]):
                shutil.rmtree(results[x])
            os.makedirs(results[x])
        else:
            if os.path.exists(results[0]+"/"+results[x]):
                shutil.rmtree(results[0]+"/"+results[x])
            os.makedirs(results[0]+"/"+results[x])

    for i in range(3):
        for j in range(3):
            if os.path.exists("results"+dirs[i][j]):
                shutil.rmtree("results"+dirs[i][j])
            os.makedirs("results"+dirs[i][j])

            if(j==0):
                for k in range(len(data_saves[i][0])):
                    plt.imsave("results"+dirs[i][j]+str(k+1)+".jpeg", data_saves[i][0][k])
            if(j==1):
                for k in range(len(data_saves[i][1])):
                    Image.fromarray((data_saves[i][1][k] * 255).astype(np.uint8).reshape(256, 256)).save("results"+dirs[i][j]+str(k+1)+".jpeg")
            if(j==2):
                pred=model_best.predict(data_saves[i][0])
                for k in range(len(pred)):
                    Image.fromarray((pred[k] * 255).astype(np.uint8).reshape(256, 256)).save("results"+dirs[i][j]+str(k+1)+".jpeg")

# %%
def predict_classwise():
    
    category_= ['train/','test/','validation/']
    tumor    = ['benign/','malginant/','normal/']
    dirs_    = ['tumor/','true/','predicted/']

    if os.path.exists("classwise_results/"):
            shutil.rmtree("classwise_results/")
    os.makedirs("classwise_results/")

    for i in range(3):
        if os.path.exists("classwise_results/"+category_[i]):
            shutil.rmtree("classwise_results/"+category_[i])
        os.makedirs("classwise_results/"+category_[i])
        for j in range(3):
            if os.path.exists("classwise_results/"+category_[i]+tumor[j]):
                shutil.rmtree("classwise_results/"+category_[i]+tumor[j])
            os.makedirs("classwise_results/"+category_[i]+tumor[j])
            for k in range(3):
                path_="classwise_results/"+category_[i]+tumor[j]+dirs_[k]
                if os.path.exists(path_):
                    shutil.rmtree(path_)
                os.makedirs(path_)

                if(k==0):
                    X=np.asarray(l[i][j][0],dtype=np.float32)/255
                    for m in range(len(X)):
                        plt.imsave(path_ + str(m) + ".jpeg", X[m])
                if(k==1):
                    y = np.asarray(l[i][j][1],dtype=np.float32)/255
                    for m in range(len(y)):
                        Image.fromarray((y[m]* 255).astype(np.uint8).reshape(256, 256)).save(path_ + str(m) + ".jpeg")
                if(k==2):     
                    X=np.asarray(l[i][j][0],dtype=np.float32)/255
                    pred = model_best.predict(X)
                    for m in range(len(pred)):
                        Image.fromarray((pred[m]* 255).astype(np.uint8).reshape(256, 256)).save(path_ + str(m) + ".jpeg")
                    print(path_+" : "+str(DiceAccuracy(np.asarray(l[i][j][1],dtype=np.float32)/255,pred).numpy()[0])+"\n")

# %%
predict_data()
predict_classwise()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48556/3054858990.py in <module>
# ----> 1 predict_data()
#       2 predict_classwise()
#
# NameError: name 'predict_data' is not defined
